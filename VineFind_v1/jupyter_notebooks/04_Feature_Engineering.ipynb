# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# ## Objectives
#
# * The objective of this notebook is to perform feature engineering to prepare the dataset for modeling. This includes splitting the data into training, validation, and test sets; generating a list of relevant variables; handling missing data through categorical imputation for variables such as `country`, `province`, and `variety`; and applying categorical encoding techniques to transform categorical variables into a suitable format for machine learning algorithms.
#
# ## Inputs
#
# *  VineFind_v1\outputs\datasets\cleaned\wine_reviews_cleaned.pkl
#
# ## Outputs
#
# * Train, validate and test datasets
# * Generate a list with variable
# * Categorical Imputation for the missing data in the variable
#     * `country`
#     * `province`
#     * `variety`
# * Categorical Encoding
#
#
# ## Additional Comments
#
# * In case you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Set up

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %% [markdown]
# ## Change Working Directory

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\purpk\\OneDrive\\Documents\\Coding\\VineFind\\VineFind\\VineFind_v1\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\purpk\\OneDrive\\Documents\\Coding\\VineFind\\VineFind\\VineFind_v1'

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Data

# %%
df = pd.read_pickle('outputs/datasets/cleaned/wine_reviews_cleaned.pkl')

df.head(1)
# Out:
# Dataframe size in bytes: 167508985
# Dataframe size in MB: 159.74901676177979
#   country                                        description  \
# 0      US  this tremendous 100% varietal wine hails from ...
#
#          designation  points  price    province     region_1 region_2  \
# 0  Martha's Vineyard      96  235.0  California  Napa Valley     Napa
#
#               variety winery taster_name taster_twitter_handle title
# 0  Cabernet Sauvignon  Heitz        <NA>                  <NA>  <NA>

# %% [markdown]
# # Section 1: Split Train, Validate and Test Set

# %% [markdown]
# Section 1 content

# %%
#https://www.youtube.com/watch?v=k9cuKNnLF9w&t=46s&ab_channel=Koolac

# Define features and target
x = df.drop(columns=['country'])
y = df['country']

# split into test and train
x_main, x_test, y_main, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

x_train, x_val, y_train, y_val = train_test_split(x_main, y_main, test_size=0.1, random_state=42)

print(f"Train shape: {x_train.shape}")
print(f"Validation shape: {x_val.shape}")  
print(f"Test shape: {x_test.shape}")
# Out:
# Train shape: (121989, 12)
# Validation shape: (13555, 12)
# Test shape: (33886, 12)

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * If you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
    # create here your folder
    # os.makedirs(name='')
except Exception as e:
    print(e)
